# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.io.wavfile import read as read_wavfile

# %%
wav_fnames = ["test_60.wav", "almost_silence_60.wav", "speech_60.wav"]

# %%
samplerates = []
data_arrays = []
for wav_fname in wav_fnames:
    samplerate, data = read_wavfile(wav_fname)
    print(f"Processing {wav_fname}")
    print(f"number of channels = {data.shape[1]}")

    length = data.shape[0] / samplerate
    print(f"length = {length}s")
    samplerates.append(samplerate)
    data_arrays.append(data)
# Out:
# Processing test_60.wav
# number of channels = 2
# length = 60.0s
# Processing almost_silence_60.wav
# number of channels = 2
# length = 60.0s
# Processing speech_60.wav
# number of channels = 2
# length = 60.0s

# %%
fig, axes = plt.subplots(3)
for ax, data in zip(axes, data_arrays):
    length = data.shape[0] / samplerate
    time = np.linspace(0., length, data.shape[0])
    ax.plot(time, data[:, 0], label="Left channel")
    ax.plot(time, data[:, 1], label="Right channel")
    ax.legend()
    #ax.xlabel("Time [s]")
    #ax.ylabel("Amplitude")
#plt.show()
# Out:
# /Users/alexanderjunge/Code/langdev/.venv/lib/python3.7/site-packages/IPython/core/pylabtools.py:132: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
